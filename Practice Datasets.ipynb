# %% [markdown]
# # Practice datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
os.chdir("C:\\Users\\Dinesh\\Desktop\\DataSets")

# %%
data=pd.read_csv("turnover.csv")

# %%
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
data.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'sales', 'salary'],
#       dtype='object')

# %%
data.describe() #the maximum no. of employees are have satistaction level is near 0.6
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
data['left'].value_counts()  #3571 employees are left from company
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
data.var()
# Out:
# satisfaction_level          0.061817
# last_evaluation             0.029299
# number_project              1.519284
# average_montly_hours     2494.313175
# time_spend_company          2.131998
# Work_accident               0.123706
# left                        0.181411
# promotion_last_5years       0.020817
# dtype: float64

# %%
data.cov() #comparision b/w the two variables
            #for example if one of the satisfaction level of left if it is high and compare to the same satisfaction 
            #level of left is low then covaraince shows the negative value. if they show both high value or low values
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               0.061817         0.004469       -0.043814
# last_evaluation                  0.004469         0.029299        0.073703
# number_project                  -0.043814         0.073703        1.519284
# average_montly_hours            -0.248945         2.904356       25.683271
# time_spend_company              -0.036618         0.032888        0.354166
# Work_accident                    0.005133        -0.000428       -0.002055
# left                            -0.041128         0.000479        0.012488
# promotion_last_5years            0.000919        -0.000214       -0.001078
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.248945           -0.036618
# last_evaluation                    2.904356            0.032888
# number_project                    25.683271            0.354166
# ...

# %%
data.corr() #it represents the direction of comparing of two features
            # for example the one of the feature is strictly increasing and another feature also strictly increasing then it
            # shows 1. if it is opposite then it inverse represents -1.
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105021       -0.142970
# last_evaluation                  0.105021         1.000000        0.349333
# number_project                  -0.142970         0.349333        1.000000
# average_montly_hours            -0.020048         0.339742        0.417211
# time_spend_company              -0.100866         0.131591        0.196786
# Work_accident                    0.058697        -0.007104       -0.004741
# left                            -0.388375         0.006567        0.023787
# promotion_last_5years            0.025605        -0.008684       -0.006064
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.020048           -0.100866
# last_evaluation                    0.339742            0.131591
# number_project                     0.417211            0.196786
# ...

# %%
data.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# sales                     object
# salary                    object
# dtype: object

# %%
data['number_project'].unique()
# Out:
# array([2, 5, 7, 6, 4, 3], dtype=int64)

# %%
data.pivot_table(data,index="salary") #this shows the splitting a salary wise of the features mean
# Out:
#         Work_accident  average_montly_hours  last_evaluation      left  \
# salary
# high         0.155214            199.867421         0.704325  0.066289
# low          0.142154            200.996583         0.717017  0.296884
# medium       0.145361            201.338349         0.717322  0.204313
#
#         number_project  promotion_last_5years  satisfaction_level  \
# salary
# high          3.767179               0.058205            0.637470
# low           3.799891               0.009021            0.600753
# medium        3.813528               0.028079            0.621817
#
#         time_spend_company
# salary
# high              3.692805
# low               3.438218
# medium            3.529010

# %%
data['satisfaction_level'].hist(bins=10) #the maximum number of employees satisfaction level is 0.8

# %%
data['number_project'].hist(bins=12) #the maximum no. of employees done a projects are 4

# %%
data.boxplot(column='satisfaction_level',by="left") #it represents the maximum no of employees are have a satisfaction level 
            #between 0.5 to 0.8 are doesnot left from company

# %%
data.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
data["salary"].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
data.pivot_table(index="salary")
# Out:
#         Work_accident  average_montly_hours  last_evaluation      left  \
# salary
# high         0.155214            199.867421         0.704325  0.066289
# low          0.142154            200.996583         0.717017  0.296884
# medium       0.145361            201.338349         0.717322  0.204313
#
#         number_project  promotion_last_5years  satisfaction_level  \
# salary
# high          3.767179               0.058205            0.637470
# low           3.799891               0.009021            0.600753
# medium        3.813528               0.028079            0.621817
#
#         time_spend_company
# salary
# high              3.692805
# low               3.438218
# medium            3.529010

# %%
data.pivot_table(index="left")
# Out:
#       Work_accident  average_montly_hours  last_evaluation  number_project  \
# left
# 0          0.175009            199.060203         0.715473        3.786664
# 1          0.047326            207.419210         0.718113        3.855503
#
#       promotion_last_5years  satisfaction_level  time_spend_company
# left
# 0                  0.026251            0.666810            3.380032
# 1                  0.005321            0.440098            3.876505
